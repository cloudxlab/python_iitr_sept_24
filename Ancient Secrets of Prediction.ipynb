# %% [markdown]
# # Ancient Secrets of Prediction
#
# During the world war, the army need to predict the extact angle at which a bomb need to be thrown. Or predict the position where bomb will hit. In the ancient egypt, they need to predict the time of Solar eclips and the rains. If you look closely, every human science is evolved around predictions. We predict for survival. Actually, the brain roles is to predict for survival. The predictions are based on what we learnt from the past.
#
# As part of this tutorial, we are going to learn to predict using basic mathematics. This is usually called Machine Learning. We would start with extremely simple example and then we will gradually reach image recognition.
#
# We are not going to use any libraries such as Numpy, Scikit learn or Tensorflow. We will be coding most of the algorithms from scratch using Python. So, make yourselves confortable with Python.

# %% [markdown]
# ## Simple Two variables
#
# **Q:** *On your first trip to super market, you purchased **three** apples and your overall expense was **six** dollars. On your second trip, you purchased **five** apples and it costed you **eight** dollars. Please note that the total expense also includes parking charges which is same in both the case.
# If you have to go to supermarket to buy **ten** apples, how much will it cost?*

# %% [markdown]
# Before going further, please think for a moment and try to solve it.
#
# -----

# %% [markdown]
# To begin with, I want to stick to a standard formulation of such problem. So, I will introduce some symbols. These are pretty simple.
#
# We can simply say:
#
# $$ Expense = parking\_charges + cost\_of\_apple * apples $$
#
# Or we can say, in general formal notation:
#
# $$y = \beta0 + \beta{1}*x1$$
# Where:
#
# $y - Expense$
#
# $\beta{0} - Fixed\ cost\ i.e.\ parking$
#
# $\beta{1} - Cost\ of\ apples$
#
# You can also represent it using the line. Where y axis has expenses and x axis represents apples.
# ![image.png](attachment:image.png)
#
# All we need to figure out is the equation of line.

# %% [markdown]
# Now, lets fill-in the values. For the first trip, the equation is:
# $$6 = \beta0 + \beta{1}*3$$
#
# And for your second trip, the equation is:
# $$8 = \beta0 + \beta{1}*5$$
#
# Can you solve these equations for $\beta0\ and\ \beta{1}?$
#
# If you subtract first equation from second equation, you will get: $8 - 6 = \beta{1}*2$
# Which means $\beta{1}$ is 1
#
# If you take this value of $\beta{1}$ and substitute in Equation 1. You can compute $\beta{0}$:
#
# $6 = \beta0 + 1 * 3$
# $\beta0 = 3$
#
# So, your final equation is: $y = 3 + 1*x1$
#
# Now, we can answer the question about the expenses for 10 apples.
# $$y = 3 + 1*10 = 13$$
#
# **Expense is 13**

# %%
import numpy as np
y = [8, 6]
x = [5, 3]
m = (y[0] - y[1])/(x[0]- x[1])
c = y[0] - m*x[0]
model = np.array([m,c])

ypred = model.dot([10, 1])
ypred
# Out:
# 13.0

# %% [markdown]
# ## A simple three variables equation

# %% [markdown]
# Very Simple right? The main idea was to give you an overview of symbols we are going to use.
#
# So, we figured out the model. The model is basically the line that is going thru the data points and once we have the model, we can quickly predict the outcome for unseen values.
#
# Now, let's level-up the game. What if we have three variables in the equation.
#
# Imagine that we are buying apples and mangoes this time and there is a parking charges on every trip.
#
# Here is the details of various expenses:
#
# $1 Apple + 1 Mango + Parking = 35$
#
# $3 Apples + 2 Mangoes + Parking = 75$
#
# $4 Apples + 3 Mangoes + Parking = 105$
#
# $5 Apples + 5 Mangoes + Parking = ???$

# %% [markdown]
# Before going further, Please take time to solve this.

# %% [markdown]
# The approach to solving these three variable equations is to reduce these equations into two variable and then reduce two equations into one equation and solve it.

# %% [markdown]
# Lets rewite these equations:
#
# $A + M + P = 35$
#
# $3A + 2M + P = 75$
#
# $4A + 3M + P = 105$
#
#
# If we subtract first equation from second, we would get:
# $2A + M = 40$
#
# If we subtract second equation from third, we would get:
# $A + M = 30$

# %% [markdown]
# Now, if subtract these last two equations, M will be eliminated, we will be able to find the value of A.
#
# A = 10
#
# Now, with this we can find value of M: 10 + M = 30
#
# Therefore, M = 20
#
# Now, putting it back in first equation, we can find Parking charges:
#
# 10 + 20 + P = 35
# P = 5
#
# Now, once we know these three values, we can answer all the combinations of apples, mangoes and parking:
# $5 Apples + 5 Mangoes + Parking = 5*10 + 5*20 + 5 = 155$

# %% [markdown]
# I am sure that most of the people would have no dificulty in following so far.
#
# We can actually solve the consecutive equations of any number of variable by following the same process as long as the equations are unique.
#
# For example, you can not find values of A, M, P from these three equations:
#
# $A + M + P = 35$
#
# $3A + 3M + 3P = 105$
#
# $2A + 2M + 2P = 70$

# %% [markdown]
# ## Solving it using code in Python

# %%
#TODO: Insert a video of the animation

# %%
# It has two parts to it. In the first we will eliminate the variables as we go from top to bottom.
def normalize(E):
    for i in range(len(E)):
        for j in range(i+1, len(E)):
            mult = E[j][i]/E[i][i]
            for k in range(i, len(E[i])):
                E[j][k] -= E[i][k]*mult
    return E

# %%
# The second part involves solving the variables from bottom up:
def solve_normalized(E):
    solution = [0 for _ in range(len(E))]
    i = len(E) - 1
    k = len(E[0]) - 2
    while i > -1:
        row = E[i]
        sm = 0
        for kk in range(k+1, len(row) - 1):
            sm += row[kk]*solution[kk]
        solution[k] = (row[-1] - sm)/row[k]
        i -= 1
        k -= 1
    return solution

# %%
def solve(E):
    E = normalize(E)
    return solve_normalized(E)

# %%
# Lets test it out
eqns = [
    [1, 1, 1, 35],
    [3, 2, 1, 75],
    [4, 3, 1, 105]
   ]
solve(eqns)
# Out:
# [10.0, 20.0, 5.0]

# %% [markdown]
# It works! You can try it with other consecutive equations.

# %% [markdown]
# Question: If you have m equations, how many times will the loop run? Or what will be the order of complexity?

# %% [markdown]
# The number of times the loop runs is of the order of approximately $n^3$ if $n$ is the number of equations or number of variables.

# %% [markdown]
# If solving 4 variables equations is taking 1000 ms, solving 8 variables equations will take approximately how much time?
#
# - A. 2000 ms
# - B. 8000 ms
# - C. 1000 ms
# - D. Can't predict

# %% [markdown]
# The answer is B.
#
# This also means that solving 40 variables is going to take 1 millions ms i.e. 1000 seconds.

# %% [markdown]
# ## Solving Quadratic equation

# %% [markdown]
# Now, imagine that the relationship between input and output is non linear.
#
# Say, you are have a website. If the traffic on your website is increasing, you need to add more servers. So, you need to predict the traffic on your website. The traffic is a non-linear function of time. It is basically a second-degree polynomial.
#
# | time   | traffic |
# | ----| --- |
# | 1   |6    |
# | 2   |12   |
# | 3   |20   |
# | 4   |??   |
#
# We need to predict the value of traffic at time = 4.
#
# How would we proceed? Give it a try by yourselves before proceeding.
#
# Please note that it is a very real scenerio. People do use this technique to predict the traffic.

# %% [markdown]
# Hint: assume the equation to be $traffic = a*t^2 + b*t + c$ and solve it for a, b and c

# %% [markdown]
# Solution:
#
# After placing the values of t in this equation, we get three consecutive equations for a, b and c:
#
# $ a +  b + c = 6$
#
# $4a + 2b + c = 12$
#
# $9a + 3b + c = 20$

# %%
# Lets use the above created code:
eqn = [[1, 1, 1, 6], [4, 2, 1, 12], [9, 3, 1, 20]]
result = solve(eqn)

# %%
result
# Out:
# [1.0, 3.0, 2.0]

# %% [markdown]
# Now using these values we can calculate the traffic at t = 4
#
# $traffic = a*t^2 + b*t + c = 1.0*4^2 + 3.0*4 + 2.0 = 16 + 12 + 2 = 30$

# %% [markdown]
# Lets make it a bit more automatic.
# We can express $a*t^2 + b*t + c$ as matrix multiplication of two things:

# %% [markdown]
# $$a*t^2 + b*t + c = \begin{vmatrix} a & b & c\end{vmatrix} \times \begin{vmatrix}
# t^2 \\
# t \\
# 1
# \end{vmatrix}$$

# %%
model = np.array([[1.0, 3.0, 2.0]])
t = np.array([4, 5, 6, 7, 8, 9])
t_sq = t*t
ones = np.ones(len(t))

# %%
X = np.stack([t_sq, t, ones])

# %%
X
# Out:
# array([[16., 25., 36., 49., 64., 81.],
#        [ 4.,  5.,  6.,  7.,  8.,  9.],
#        [ 1.,  1.,  1.,  1.,  1.,  1.]])

# %%
model @ X
# Out:
# array([[ 30.,  42.,  56.,  72.,  90., 110.]])

# %%
def multiply_vectors(A, B):
    out = []
    for i in range(len(A)):
        out.append(A[i]*B[i])
    return sum(out)

# %%
multiply_vectors(result, [4**2, 4, 1])
# Out:
# 30.0

# %% [markdown]
# If we want to fit a polynomial of n degree, many distinct data points do we need:
#
# 1. $n^2$
# 2. n + 1
# 3. 1
# 4. Impossible to determine
#
# Answer: n+1

# %%
# Lets try to automate entire process

def solve_poly(x, y, xp):
    eqns = []
    for i in range(len(x)):
        eqn = [y[i]]
        xcoeff = 1
        for _ in range(len(x)):
            eqn.append(xcoeff)
            xcoeff *= x[i]
        eqn.reverse()
        eqns.append(eqn)
#     print(eqns)
    coeff = solve(eqns)
#     print(coeff)
    xpows = []
    xpow = 1
    for _ in range(len(x)):
        xpows.append(xpow)
        xpow *= xp
    xpows.reverse()
    return multiply_vectors(coeff, xpows)

# %%
solve_poly([1,2, 3], [6, 12, 20], 4)
# Out:
# 30.0

# %% [markdown]
# ## Linear Approximation

# %% [markdown]
# So far we have assumed that the curve is fitting perfectly. What if the curve doesn't fit properly? This could be because of multiple reasons:
# 1. The underlying relationship is fairly complex
# 2. There could be noise in the data

# %% [markdown]
# Imagine, there is a factory whose input and output are given as follows:
#
# | input   | output |
# | ---- | ---       |
# | 1   |8      |
# | 2   |11   |
# | 3   |16     |
# | 4   |??     |

# %% [markdown]
# Before we proceed, lets try to plot this data

# %%
import matplotlib.pyplot as plt

# %%
# plt.plot([1, 3], [8, 15], 'r-', label='A')
# plt.plot([1, 3], [7.5, 16], 'b--', label='B')
plt.scatter([1, 2, 3], [ 8, 11, 16])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Through these three points, there is not a single line that fits perfectly. Every line is having some error. We just need to find a line that fits the best. How do we define the criteria for best fitting line?

# %% [markdown]
# To start with lets assume the equation of line to be $y = mx + c$
#
# As per this line, there will be certain predicted values and there are some actual values. Let us define error sum of individual error. And the individual error to be square of predicted minus actual.

# %% [markdown]
# The overall error $E = (m*1 + c - 8)^2 + (m*2 + c - 11)^2 + (m*3 + c - 16)^2$

# %% [markdown]
# **AIM: We need to find those values of m and c for which E is minimum.**

# %% [markdown]
# If you plot the above equation such that E is on y-axis and m is on x-axis while keeping the c = 0. The graph would look like this.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# You can find it here: https://www.desmos.com/calculator/nnzpkdnhd2

# %% [markdown]
# Similarly, if you keep m = 0, the plot between E and c would look the same.
#
# The question still remains, at what values of m and c, E would be minimum??

# %% [markdown]
# ## Differentiation - Revisiting Basics

# %% [markdown]
# ### What is Differentiation / Derivative
#
# In differentiation, we basically compute the rate of change if something with respect to something else. It is also known as the derivative. For example, rate of change of distance with respect to time is called speed and rate of change of speed with respect to time is called acceleration:
#
#
# x = Distance
#
# v = speed = $\frac{\partial x}{\partial t}$
#
# acceleration =$\frac{\partial v}{\partial t}$
#
# You can think of $\partial == \Delta$

# %% [markdown]
# So, we can say, speed = $\frac{\partial x}{\partial t}$ = $\frac{(distance2 - distance1)}{time2 - time1}$
#
# The most importance missing part in this is that the difference in time is very small.
#
# Let's derive the derivates of some important functions. Please avoid memorizing. Try deriving each formula going forth.

# %% [markdown]
# The other way to look at a function would be like a transformation. The box 'f' here refers to a transformation. We are feeding x and it is giving y.
#
# ![image.png](attachment:image.png)
#
# Say, you are running Ad campaigns on Google, the y represents the total number of clicks and x represents the spent money.
#
# The $\frac{\partial y}{\partial x}$ is basically the rate of change of output with respect to input.

# %%
import math
def myfun(x):
    if x > 20 or x < -20:
        return abs(x)
    else:
        return x*x

# %%
myfun(10)
# Out:
# 100

# %%
def dyd(f, x):
    d = 1e-10
    f1 = f(x + d)
    f0 = f(x)
    return (f1 - f0)/d

# %%
dyd(myfun, 30)
# Out:
# dx: 1e-10
# f1: 30.0000000001
# f0: 30
# 0.999982319171977

# %% [markdown]
# The other way to look at derivative is that it is a tangent at a point on the curve.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![220px-Tangent_function_animation.gif](attachment:220px-Tangent_function_animation.gif)

# %%
# At maxima and minima, the tangent is horizontal. slope is zero. first derivative is zero.

# At maxima, the slope goes from +ive to -ive. Rate of change of slope is -ive. Second devative is -ive.
# At minima, the slope goes from -ive to +ive. Therefore, Rate of change of slope is +ive. Second devative is +ive.

# %% [markdown]
# ## Differentiation Usecases
#
# The main usecase of differentiation is find the minimum value or maximum value of a function. In machine learning, Gradient Descent, Ordinary least squares, Backpropagation and XGBoost use the differentiation for finding minimum error.
#
# Further, the differentiation is used in many problems in signal processing and computer vision.

# %% [markdown]
# ### Simple Examples - Constant

# %% [markdown]
# if let us say, we are given $y = 5$, what will be rate of change of y with respect to x?
#
# The answer is zero. No matter how much you change x, y is not going to change.
#
# \begin{align}
# \frac {\partial y} {\partial x} = \frac {5 - 5} {\partial x} = 0
# \end{align}

# %% [markdown]
# ### Differentiation Example - Linear
#
# if we are give y = x, then
#
#
# At x, y1 = x
#
# At x + $\partial x$,  y2 = x + $\partial x$
#
# \begin{align}
# \frac {\partial y} {\partial x} = \frac {x + \partial x - x} {\partial x} = \frac {\partial x} {\partial x}  = 1
# \end{align}

# %% [markdown]
# ### Differentiation Example - Square
#
# If $y = x^2$,
#
# \begin{align}
# \frac {\partial y} {\partial x}
#     = \frac {(x + \partial x)^2 - x^2} {\partial x}
#     = \frac {x^2 + \partial x^2 + 2x\partial x - x^2} {\partial x}
#     = \frac {\partial x^2 + 2x\partial x} {\partial x}
#     = \partial x + 2x
#     = 2x\ because\ \partial x\ is\ very\ small
# \end{align}

# %% [markdown]
# ### Differentiation Example - Multiplication
#
# If $y = a*x$, where a is some constant
#
# \begin{align}
# \frac {\partial y} {\partial x}
#     = \frac {a*(x + \partial x) - a*x} {\partial x}
#     = \frac {a*x + a*\partial x - a*x} {\partial x}
#     = \frac {a*\partial x} {\partial x}
#     = a
# \end{align}

# %% [markdown]
# ### Differentiation Example - Chain Rule

# %% [markdown]
# Imagine that we have a scenerio like this.
# ![image.png](attachment:image.png)

# %% [markdown]
# y is a function f of z and z is a function g of x.
#
# What will be the $\frac{\partial y}{\partial x}$ ??

# %% [markdown]
# If we just follow the definition, it will be as follows:
#
# \begin{align}
# y = f(z)\\
# z = g(x)\\
# \frac{\partial y}{\partial x} = \frac{\partial f}{\partial z} * \frac{\partial g}{\partial x}
# \end{align}

# %% [markdown]
# *Question: If we have $y = (3*x + 2)^2$, what will be $\frac{\partial y}{\partial x}$ ??*

# %% [markdown]
# Solution:
#
# We can break it into two transformation and then apply chain rule:
#
# \begin{align}
# y = z^2\\
# z = 3x + 2\\
# \frac{\partial y}{\partial x} = \frac{\partial y}{\partial z} * \frac{\partial z}{\partial x} = 2 *z * 3 = 2*(3*x + 2)*3 = 18x + 12
# \end{align}

# %% [markdown]
# ### Differentiation Example - Multiplications of two function

# %% [markdown]
# If $y = f1(x) * f2(x)$, what will be $\frac{\partial y}{\partial x}$?

# %% [markdown]
# By using the first principle, we can prove that it would be:
# \begin{align}
# \frac{\partial y}{\partial x} = f1(x) * \frac{\partial f2}{\partial x} + f2(x) * \frac{\partial f1}{\partial x}
# \end{align}

# %% [markdown]
# ***Question: If $y = (2x+4) * (3x + 5)$, what will be $\frac{\partial y}{\partial x}$?***

# %% [markdown]
# ***Solution***
#
# \begin{equation*}
# \frac{\partial y}{\partial x} = f1(x) * \frac{\partial f2}{\partial x} + f2(x) * \frac{\partial f1}{\partial x} \\
# = (2x + 4) * 3 + (3x + 5)*2
# = 12x + 22
# \end{equation*}

# %% [markdown]
# ### Derivative - Finding minima or maxima
#
#
# If you notice closely, at the point of minimum or maximum, the slope of tangent is 0. The tangent is horizontal.
#
# ![220px-Tangent_function_animation.gif](attachment:220px-Tangent_function_animation.gif)

# %% [markdown]
# https://en.wikipedia.org/wiki/Derivative

# %% [markdown]
# ![image.png](attachment:d47d7b9f-0e01-4c73-98f9-ff8a26e1cabb.png)![image.png](attachment:1f4027cb-208d-47d7-98b7-dc2228b0646b.png)

# %% [markdown]
# Also, notice that at minimum, the slope first increases from negative to zero and then starts increasing. So, the rate of change of slope is positive. This means the second derivative is positive at minima.
# And at maxima, the slope first decreases to zero and then starts decreasing. This means the second derivative is negative.

# %% [markdown]
# Lets try solving couple of questions. You are given a curve $y = x^2 - 3x + 10$
#
# At what point, the tangent will be horizontal i.e. the $\frac{\partial y}{\partial x}$ will be zero?

# %% [markdown]
# \begin{equation*}
# \frac{\partial y}{\partial x} = 2x - 3 = 0 \\
# x = 1.5
# \end{equation*}
#
# So, at x = 1.5, the slope of tangent is zero. It could be minima or maxima.

# %%
def f(args):
    x1, x2 = args

# %%
f(1.5), f(1.49), f(1.51)
# Out:
# (7.75, 7.7501, 7.7501)

# %%
x1 = (10 + math.sqrt(100-48))/6
x1
# Out:
# 2.86851709182133

# %%
x2 = (10 - math.sqrt(100-48))/6
x2
# Out:
# 0.4648162415120036

# %%
def f(x):
    return x*x*x - 5*x*x + 4*x + 2

# %%
f(x1), f(x2)
# Out:
# (-4.064604931928287, 2.8794197467431006)

# %%
f(x1+0.0001), f(x2+0.0001)
# Out:
# (-4.064604895871769, 2.879419710688588)

# %% [markdown]
# Lets find the second derivative?
#
# \begin{equation*}
# \frac{\partial^2 y}{\partial x^2} = 2 \\
# \end{equation*}
#
# Since the second derivative is positive, at x = 1.5 we will find the minima.
#
# At x = 1.5 the minimum value of y is $1.5^2 - 3*1.5 + 10 = 7.75$

# %% [markdown]
# Now, lets get back to the problem where the overall loss was
#
# $E = (m*1 + c - 8)^2 + (m*2 + c - 11)^2 + (m*3 + c - 16)^2$
#
# Lets try to find the first derivatives of E with respect to m as well as c.
#
# \begin{equation*}
# \frac{\partial E}{\partial m} = 2*(m + c -8) + 2*2(2m + c - 11) + 2*3*(3m + c - 16) = 28m + 12c - 156
# \frac{\partial E}{\partial c} = 2*(m + c -8) + 2*(2m + c - 11) + 2*(3m + c - 16) = 12m + 6c - 70
# \end{equation*}
#
# If you differentiate further wrt to m as well as c, the values are positive, therefore, we are going to find minima.
#
# Equating both $\frac{\partial E}{\partial m}$ and $\frac{\partial E}{\partial c}$ to zero in order to find minima.
#
#
# 28m + 12c - 156 = 0
#
# 12m + 6c - 70 = 0
#
# We can use the above code to solve these equations:

# %%
solve([[28, 12, 156], [12, 6, 70]])
# Out:
# [3.999999999999996, 3.6666666666666763]

# %% [markdown]
# so, m = 4 and c = 3.7

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.55.6-cp312-cp312-macosx_10_13_universal2.whl.metadata (166 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/sandeepgiri/miniconda3/envs/spider2_env/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/sandeepgiri/miniconda3/envs/spider2_env/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/sandeepgiri/miniconda3/envs/spider2_env/lib/python3.12/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sandeepgiri/miniconda3/envs/spider2_env/lib/python3.12/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sandeepgiri/miniconda3/envs/spider2_env/lib/python3.12/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/sandeepgiri/miniconda3/envs/spider2_env/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.10.0-cp312-cp312-macosx_11_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 25.8 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.3.1-cp312-cp312-macosx_11_0_arm64.whl (255 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.6-cp312-cp312-macosx_10_13_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 27.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-macosx_11_0_arm64.whl (65 kB)
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.55.6 kiwisolver-1.4.8 matplotlib-3.10.0

# %%
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Lets try to plot the line y = 4x + 3.7,
# at x = 0, y = 3.7 
# at x = 3, y = 15.7

plt.plot([0, 3], [3.7, 15.7], 'r-', label='A')
plt.scatter([1, 2, 3], [ 8, 11, 16])
plt.legend()
plt.show()

# %% [markdown]
# You can see we have found the best fitting line. Now, we can use this line to predict.
#
# At x = 4, $y = 4*4 + 3.7 = 19.7$

# %%
#Lets confirm if it is right.
# Lets try in nearby points to (4.0, 3.7)
all_m_c = [(4.0, 3.7), (4.1, 3.7), (3.9, 3.7), (4.0, 3.8), (4.0, 3.6)]
for m, c in all_m_c:
    E = (m*1 + c - 8)**2 + (m*2 + c - 11)**2 + (m*3 + c - 16)**2
    print("m: %.2f, c: %.2f, Error: %.4f" % (m, c, E))
# Out:
# m: 4.00, c: 3.70, Error: 0.6700
# m: 4.10, c: 3.70, Error: 0.8500
# m: 3.90, c: 3.70, Error: 0.7700
# m: 4.00, c: 3.80, Error: 0.7200
# m: 4.00, c: 3.60, Error: 0.6800

# %% [markdown]
# So, you can see the minimum value exists at (4.0, 3.7)

# %% [markdown]
# https://en.wikipedia.org/wiki/Ordinary_least_squares

# %% [markdown]
# Assignment:
#
# - Solve by hand - find the line that fits these data points - [1, 4], [2, 6], [3, 9]
# - Try deriving the derivative of x^3 algebrically just like we did for y = x^2
# - Write a function that differentiates / computes derivative of another function
# - Go through the derivatives of various common functions such log, sin, cos, tan, 1/x, x**n...
# - Using the derivatives find the minima or maxima of the curve y = x**2 - 4x + 20
# - Practice the chain rule a little more: y = (sqrt(x) + x**2 - 40x)**2

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# ## Stop before backprop
#
# https://cloudxlab.com/blog/backpropagation-from-scratch/

# %% [markdown]
# ## A real example of linear regression

# %%
def diff(fn, x):
    delta = 0.000000000001
    y = fn(x)
    x1 = x + delta
    y1 = fn(x1)
    return (y1 - y)/delta

# %%
def sq(x):
    return x*x

# %%
diff(sq, 2)
# Out:
# 4.000355602329364

# %%
def cube(x):
    return x*x*x

diff(cube, 2)
# Out:
# 12.001066806988092

# %%
def myf(x):
    return x*x*x + x*x + x + 10

diff(myf, 2)
# Out:
# 17.003287666739197

# %%
# 3x2 + 2x + 1
x = 2
3*x*x + 2*x + 1
# Out:
# 17

# %%
abs(-2)
# Out:
# 2

# %%
def myf(x):
    return abs(x)

diff(myf, -0.00000001)
# Out:
# -0.9999999999994795

# %%
def E1(m, c):
    return 5*m + c*c

def E(m, c):
    return m*c

# compute dE/dm at m = 10, c = 5
m,c = 10, 5
delta = 1e-10
E1 = E(m, c)
E2 = E(m + delta, c)
dE_dm = (E2 - E1)/delta
E2 = E(m, c + delta)
dE_dc = (E2 - E1)/delta
dE_dm, dE_dc
# Out:
# (5.000018177270249, 10.000036354540498)

# %%
import numpy as np

# The first argument is the function, 
# second argument is the idx of the input with respect to which we are differentiating.
# Third arguments is a variable arguments - there can be many values. The function is called with these values.

def diffp(fn, idx, *args):
    delta = 0.000000000001
    
    # Call the underlying function with args as such
    y = fn(*args)
    
    # Now, increase only one input - at idx.
    args = list(args)
    args[idx] += delta
    
    # Now, calulate the output after changing one of the inputs a little bit.
    y1 = fn(*args)
    return (y1 - y)/delta

# %%
def fn(x1, x2):
    return 5*x1 + x2*x2

# %%
fn(10, 3)
# Out:
# 59

# %%
diffp(fn, 0, 10, 3)
# Out:
# 5.002220859751105

# %%
diffp(fn, 1, 10, 3)
# Out:
# 5.996980689815246

# %%
from random import random
xx = []
yy = []
for x in range(0, 10):
    y = 4*x+ 20 + 6*random()
    xx.append(x)
    yy.append(y)

# %%
plt.scatter(xx, yy)

# %%
def sum(*args):
    s = 0
    for i in args:
        s += i
    return s

# %%
sum(1,2,3)
# Out:
# 6

# %%
sum(1,2,3, 4)
# Out:
# 10

# %%
def diffp(fn, idx, *args):
    delta = 0.000000000001
    
    # Call the underlying function with args as such
    y = fn(*args)
    
    # Now, increase only one input - at idx.
    args = list(args)
    args[idx] += delta
    
    # Now, calulate the output after changing one of the inputs a little bit.
    y1 = fn(*args)
    return (y1 - y)/delta

# %%
def fn(x1, x2):
    return 5*x1 + x2*x2

# %%
args=[10, 5]
diffp(fn, 0, *args)
# Out:
# 5.002220859751105

# %%
diffp(fn, 1, *args)
# Out:
# 10.00444171950221

# %%
import numpy as np

# Generate 100 random numbers
X = 2*np.random.random((100, 1))

# %%
X.shape
# Out:
# (100, 1)

# %%
# Now, let us generate the values of y corresponding to a line with slope 3 and intercept 4
# plus some noise
y = 4 + 3 * X + .3*np.random.randn(100, 1)

# %%
y.shape
# Out:
# (100, 1)

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(11,4))
plt.scatter(X, y)
plt.show()

# %%
def error(m, c, X, y):
    ypred = m*X + c
    err = ypred-y
    return np.sum(err*err)

# %%
error(4, 3, X, y)
# Out:
# 46.77506693801228

# %%
error(3.9, 3.1, X, y)
# Out:
# 39.9237456780672

# %%
m = 10
c = 0
args = [m, c, X, y]
de_dm = diffp(error, 0, *args)
de_dm
# Out:
# 1063.199306372553

# %%
de_dc = diffp(error, 1, *args)
de_dc
# Out:
# 571.1626727133989

# %%
# Decrease m but how much?
lr = 0.01 
m -=  lr * de_dm
c -= lr * de_dc

# %%
# Out:
# (-0.6319930637255311, -5.711626727133989)

# %%
args = [m, c, X, y]
de_dm = diffp(error, 0, *args)
de_dc = diffp(error, 1, *args)

# %%
de_dm, de_dc
# Out:
# (-2848.5374059528112, -2652.0865503698587)

# %%
# Increase m but how much?
lr = 0.001 
m -=  lr * de_dm
c -= lr * de_dc
m, c

# %%
m, c
# Out:
# (18.01628630142659, 12.57285475730896)

# %%
args = [m, c, X, y]
de_dm = diffp(error, 0, *args)
de_dc = diffp(error, 1, *args)
de_dm, de_dc
# Out:
# (5638.867150992155, 4663.888830691576)

# %%
lr = 0.001 
m -=  lr * de_dm
c -= lr * de_dc
m, c
# Out:
# (12.377419150434434, 7.908965926617384)

# %%
args = [m, c, X, y]
de_dm = diffp(error, 0, *args)
de_dc = diffp(error, 1, *args)
de_dm, de_dc
# Out:
# (3234.163159504533, 2615.7067622989416)

# %%
lr = 0.001 
m -=  lr * de_dm
c -= lr * de_dc
m, c
# Out:
# (9.143255990929902, 5.293259164318442)

# %%
args = [m, c, X, y]
de_dm = diffp(error, 0, *args)
de_dc = diffp(error, 1, *args)
de_dm, de_dc
# Out:
# (1873.5590856522322, 1464.2864698544145)

# %%
lr = 0.001 
m -=  lr * de_dm
c -= lr * de_dc
m, c
# Out:
# (5.396137819625437, 2.3646862246096134)

# %%
args = [m, c, X, y]
de_dm = diffp(error, 0, *args)
de_dc = diffp(error, 1, *args)
de_dm, de_dc
# Out:
# (313.4914550173562, 143.9843799744267)

# %%
lr = 0.001 
m -=  lr * de_dm
c -= lr * de_dc
m, c
# Out:
# (5.082646364608081, 2.2207018446351867)

# %%
args = [m, c, X, y]
de_dm = diffp(error, 0, *args)
de_dc = diffp(error, 1, *args)
de_dm, de_dc
# Out:
# (202.73205336707179, 53.83071766118519)

# %%
lr = 0.001 
m -=  lr * de_dm
c -= lr * de_dc
m, c
# Out:
# (4.879914311241009, 2.1668711269740015)

# %%
m = 100
c = 0
ms = [m]
cs = [c]
errors = [error(m,c, X, y)]

for i in range(300):
    args = [m, c, X, y]
    de_dm = diffp(error, 0, *args)
    de_dc = diffp(error, 1, *args)
#     print(f"de_dm, de_dc: {de_dm, de_dc}")
    lr = 0.001 
    m -=  lr * de_dm
    c -= lr * de_dc
    ms.append(m)
    cs.append(c)
    new_error = error(m, c, X, y)
#     new_erro_val = error(m, c, X_test, y_test)
    errors.append(new_error)
#     print(f"m, c: {m, c}")
    print(f"Error: ", new_error)
# Out:
# Error:  427878.76617164374
# Error:  183779.75707841513
# Error:  99047.99809329717
# Error:  68619.1596347176
# Error:  56302.49688440743
# Error:  50028.32982407045
# Error:  45884.90081769778
# Error:  42600.71415801851
# Error:  39714.13783461566
# Error:  37060.88386987518
# Error:  34595.60187510094
# Error:  32305.500901851967
# Error:  30177.59415018513
# Error:  28192.13298454567
# Error:  26345.142985155486
# Error:  24612.91963650683
# Error:  22993.94419398692
# Error:  21485.39850037883
# Error:  20070.127323740697
# Error:  18748.59312702395
# Error:  17521.247624002644
# Error:  16371.75524084359
# Error:  15297.23393165099
# Error:  14291.596371512715
# Error:  13350.75001990832
# Error:  12472.775130343307
# Error:  11654.290543234007
# Error:  10891.043488478459
# Error:  10174.819893919077
# Error:  9505.787857438618
# Error:  8881.420889958119
# Error:  8298.26634759751
# Error:  7752.834241259409
# Error:  7243.539808005662
# Error:  6766.557493960117
# Error:  6321.808077818353
# Error:  5906.019847274547
# Error:  5517.69301821148
# Error:  5154.2260166490705
# Error:  4814.914877956329
# Error:  4497.830982499536
# Error:  4202.230154517818
# Error:  3926.192970187715
# Error:  3668.0500483358883
# Error:  3426.917262788305
# Error:  3201.9172296145944
# Error:  2991.6546278356445
# Error:  2795.3252655176493
# Error:  2611.7331247406973
# Error:  2440.206232720851
# Error:  2280.086442593387
# Error:  2130.4418594888343
# Error:  1990.8013699589615
# Error:  1860.2487355646492
# Error:  1738.3329820472482
# Error:  1624.5848198456447
# Error:  1518.3609178249321
# Error:  1419.1143495066824
# Error:  1326.356681480169
# Error:  1239.6649686124915
# Error:  1158.7439383706296
# Error:  1083.049901871349
# Error:  1012.3883861343382
# Error:  946.4033530777924
# Error:  884.7540081618023
# Error:  827.2028571381328
# Error:  773.4168400959933
# Error:  723.186372574883
# Error:  676.2489910346596
# Error:  632.410003739248
# Error:  591.4621940799835
# Error:  553.1825505328438
# Error:  517.4296992641121
# Error:  484.0387181076501
# Error:  452.8484700066401
# Error:  423.7288646058521
# Error:  396.5165906213073
# Error:  371.10767524586964
# Error:  347.3553735446355
# Error:  325.18013615016184
# Error:  304.45534363523444
# Error:  285.1086535614189
# Error:  267.0330160459911
# Error:  250.14527131715812
# Error:  234.36852491668176
# Error:  219.6302598389456
# Error:  205.86176156235499
# Error:  193.00073068093644
# Error:  180.9858167328778
# Error:  169.766536460712
# Error:  159.28369073609687
# Error:  149.49801982315216
# Error:  140.3540815590224
# Error:  131.81111582272035
# Error:  123.82889537100378
# Error:  116.37604397937719
# Error:  109.41314994219012
# Error:  102.9082482722742
# Error:  96.83182483213545
# Error:  91.15770774832245
# Error:  85.8562885890845
# Error:  80.9038462039178
# Error:  76.27773522478303
# Error:  71.95718832727908
# Error:  67.92074436483786
# Error:  64.14971924976844
# Error:  60.62651552173928
# Error:  57.33704725480111
# Error:  54.26381747881698
# Error:  51.39273379410794
# Error:  48.71163487941654
# Error:  46.20630136317024
# Error:  43.86719229913167
# Error:  41.68153306631366
# Error:  39.639822534622816
# Error:  37.73246921707875
# Error:  35.95168424158432
# Error:  34.28784542054316
# Error:  32.733140884173814
# Error:  31.281398137220467
# Error:  29.924896406621144
# Error:  28.65776292730741
# Error:  27.474114535054436
# Error:  26.368633730302264
# Error:  25.33609135516457
# Error:  24.37126501562613
# Error:  23.470047488467355
# Error:  22.628238231817026
# Error:  21.84188186926029
# Error:  21.107259130825327
# Error:  20.421281058717305
# Error:  19.780473029248114
# Error:  19.1819408292479
# Error:  18.62276181974895
# Error:  18.100462715196286
# Error:  17.612591377697434
# Error:  17.15671302943645
# Error:  16.731181513583252
# Error:  16.333556995448117
# Error:  15.962095622041662
# Error:  15.614967321862533
# Error:  15.290825810501143
# Error:  14.98806085311858
# Error:  14.705154255718961
# Error:  14.440931840663179
# Error:  14.194027815907939
# Error:  13.96354466159641
# Error:  13.748159757163396
# Error:  13.547019840213968
# Error:  13.359105399490334
# Error:  13.183564513373476
# Error:  13.019552097940105
# Error:  12.866348874139437
# Error:  12.723210137649652
# Error:  12.589527316243254
# Error:  12.464725412091136
# Error:  12.348102542258022
# Error:  12.239144544722826
# Error:  12.137408122712866
# Error:  12.042312822758355
# Error:  11.95354049045193
# Error:  11.870590517464702
# Error:  11.793127898151726
# Error:  11.72076831473371
# Error:  11.65317028010876
# Error:  11.590067048834117
# Error:  11.531075738499423
# Error:  11.47598520733176
# Error:  11.424540078519788
# Error:  11.376455820428392
# Error:  11.331573454274764
# Error:  11.289649595690713
# Error:  11.250475295690272
# Error:  11.213887078391531
# Error:  11.17974016819804
# Error:  11.147819060987132
# Error:  11.118013725805573
# Error:  11.09013623326463
# Error:  11.064088098715123
# Error:  11.039780405505457
# Error:  11.017101236359332
# Error:  10.995861958797374
# Error:  10.976033165203624
# Error:  10.957500362352768
# Error:  10.940214615246274
# Error:  10.924071507317297
# Error:  10.909000777280163
# Error:  10.894917115376044
# Error:  10.8817288719417
# Error:  10.86944561982394
# Error:  10.857951241001777
# Error:  10.847225501831787
# Error:  10.837193497711137
# Error:  10.827836146699678
# Error:  10.819082023018494
# Error:  10.810900105991784
# Error:  10.803258117171167
# Error:  10.796126723600958
# Error:  10.789455772486212
# Error:  10.783236756857072
# Error:  10.777429131663277
# Error:  10.771991110088731
# Error:  10.766913249345675
# Error:  10.762187999084254
# Error:  10.75775272196834
# Error:  10.75361553927271
# Error:  10.749754299211082
# Error:  10.746135558132869
# Error:  10.742771919762408
# Error:  10.739622132413833
# Error:  10.736677327674775
# Error:  10.733932230034302
# Error:  10.731362064139507
# Error:  10.728970984282629
# Error:  10.72673392948946
# Error:  10.72464829386673
# Error:  10.722702316488016
# Error:  10.720874851365725
# Error:  10.719175697075878
# Error:  10.717584141156216
# Error:  10.716100219671217
# Error:  10.714714309358154
# Error:  10.713414866984106
# Error:  10.712210786072955
# Error:  10.711082053515366
# Error:  10.710021545307304
# Error:  10.709032310410347
# Error:  10.708113113477324
# Error:  10.707255214784604
# Error:  10.70644964572216
# Error:  10.705698047380809
# Error:  10.70499578484572
# Error:  10.704339648148004
# Error:  10.70372414689128
# Error:  10.703152590129218
# Error:  10.702615013175963
# Error:  10.702112783640334
# Error:  10.701644474999423
# Error:  10.701204820213833
# Error:  10.700798171793446
# Error:  10.7004149366214
# Error:  10.700060607871755
# Error:  10.699729907067765
# Error:  10.699416068389894
# Error:  10.699128096886463
# Error:  10.698857318499805
# Error:  10.698604411701208
# Error:  10.698369179445825
# Error:  10.698146766481237
# Error:  10.697938805776245
# Error:  10.697747818473731
# Error:  10.697567732807231
# Error:  10.697402154408056
# Error:  10.697244596980624
# Error:  10.697095591775437
# Error:  10.696961013502074
# Error:  10.696833048704114
# Error:  10.69671319736051
# Error:  10.69660417790744
# Error:  10.696499063121207
# Error:  10.696400537727795
# Error:  10.696309338758894
# Error:  10.69622493857565
# Error:  10.696145920129236
# Error:  10.696072120278325
# Error:  10.696002430143714
# Error:  10.695937757245538
# Error:  10.69587550444566
# Error:  10.695818015392982
# Error:  10.69576472689132
# Error:  10.695715089387116
# Error:  10.695669602315581
# Error:  10.695626325488353
# Error:  10.695586359651895
# Error:  10.69554877328343
# Error:  10.695514306290423
# Error:  10.695482184195793
# Error:  10.695452210731517
# Error:  10.695423276134306
# Error:  10.695396534033742
# Error:  10.695371569210506
# Error:  10.695348220780291
# Error:  10.69532739250253
# Error:  10.695307538655802
# Error:  10.695288173212631
# Error:  10.695269985903852
# Error:  10.695253461023212
# Error:  10.695237739453946
# Error:  10.695223188994113
# Error:  10.695210127759392
# Error:  10.695197833066796
# Error:  10.695186378530897
# Error:  10.695175130298336
# Error:  10.69516488277023
# Error:  10.695155157979487
# Error:  10.695146332615414
# Error:  10.695137561655077
# Error:  10.695129781873153
# Error:  10.695122509372757
# Error:  10.695115410754287

# %%
plt.plot(errors)

# %% [markdown]
# Exercise1:
#     - Repeat the above experiment with different dataset
#     - And break the dataset random into X_train, y_train and X_test, y_test in a ratio of 80:20
#     - Using X-Train and y_train do the gradient descent and using X_test and y_test print the error
#     - plot both the error

# %% [markdown]
#  Exercise2:
#      + Generate the non linear dataset: y = 4*x^2 + 3x - 100 + noise
#      + Now, model is y = ax ** 2 + bx + c
#      + Write your error(a, b, c, X, y)
#      + gradient descent to find a, b, c

# %%
x = np.array([1,2,3])
y = np.array([2, 3, 4])
a, b, c = 5, 5, 5
ws = np.array([a, b, c])
X = np.array([x*x, x, 1])
ypred = ws*X
# Out:
# /usr/local/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """

# %%
ws
# Out:
# array([5, 5, 5])

# %%
X
# Out:
# array([array([1, 4, 9]), array([1, 2, 3]), 1], dtype=object)

# %%
ypred
# Out:
# array([15, 35, 65])
